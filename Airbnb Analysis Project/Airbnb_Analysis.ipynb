# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
airbnb=pd.read_csv("/content/Airbnb data.csv")

# %%
airbnb.head()
# Out:
#     room_id  survey_id   host_id    room_type  country       city  borough  \
# 0  10176931       1476  49180562  Shared room      NaN  Amsterdam      NaN
# 1   8935871       1476  46718394  Shared room      NaN  Amsterdam      NaN
# 2  14011697       1476  10346595  Shared room      NaN  Amsterdam      NaN
# 3   6137978       1476   8685430  Shared room      NaN  Amsterdam      NaN
# 4  18630616       1476  70191803  Shared room      NaN  Amsterdam      NaN
#
#               neighborhood  reviews  overall_satisfaction  accommodates  \
# 0  De Pijp / Rivierenbuurt        7                   4.5             2
# 1             Centrum West       45                   4.5             4
# 2          Watergraafsmeer        1                   0.0             3
# 3             Centrum West        7                   5.0             4
# 4   De Baarsjes / Oud West        1                   0.0             2
#
#    bedrooms  bathrooms  price  minstay  \
# ...

# %%
airbnb.isnull().sum()
# Out:
# room_id                     0
# survey_id                   0
# host_id                     0
# room_type                   0
# country                 18723
# city                        0
# borough                 18723
# neighborhood                0
# reviews                     0
# overall_satisfaction        0
# accommodates                0
# bedrooms                    0
# bathrooms               18723
# price                       0
# minstay                 18723
# name                       52
# last_modified               0
# latitude                    0
# longitude                   0
# location                    0
# dtype: int64

# %%
airbnb[airbnb['name'].isnull()]
# Out:
#         room_id  survey_id   host_id        room_type  country       city  \
# 151    17557382       1476  33583311  Entire home/apt      NaN  Amsterdam
# 241     9020907       1476  19122863  Entire home/apt      NaN  Amsterdam
# 355    10152802       1476  24138541  Entire home/apt      NaN  Amsterdam
# 668     9808194       1476  18014889  Entire home/apt      NaN  Amsterdam
# 927    11247641       1476   7023284  Entire home/apt      NaN  Amsterdam
# 1448   11876707       1476  63326612  Entire home/apt      NaN  Amsterdam
# 1892    3771282       1476  10529642  Entire home/apt      NaN  Amsterdam
# 1908   12965190       1476  71299676  Entire home/apt      NaN  Amsterdam
# 2353   11579476       1476  14184874  Entire home/apt      NaN  Amsterdam
# 3812   12397008       1476    400638  Entire home/apt      NaN  Amsterdam
# 4507    6796551       1476   6073488  Entire home/apt      NaN  Amsterdam
# 5208   11109865       1476  57712541  Entire home/apt      NaN  Amsterdam
# ...

# %%
airbnb.drop(columns=['country','borough','bathrooms','minstay'],inplace=True)
airbnb.isnull().sum()
# Out:
# room_id                  0
# survey_id                0
# host_id                  0
# room_type                0
# city                     0
# neighborhood             0
# reviews                  0
# overall_satisfaction     0
# accommodates             0
# bedrooms                 0
# price                    0
# name                    52
# last_modified            0
# latitude                 0
# longitude                0
# location                 0
# dtype: int64

# %%
airbnb.dropna(inplace=True)
airbnb.isnull().sum()
# Out:
# room_id                 0
# survey_id               0
# host_id                 0
# room_type               0
# city                    0
# neighborhood            0
# reviews                 0
# overall_satisfaction    0
# accommodates            0
# bedrooms                0
# price                   0
# name                    0
# last_modified           0
# latitude                0
# longitude               0
# location                0
# dtype: int64

# %%
room_type_dict={"Room Types":room_types.index,"Room Counts":room_types.to_list()}
room_type_df=pd.DataFrame(room_type_dict)
room_type_df
# Out:
#         Room Types  Room Counts
# 0  Entire home/apt        14937
# 1     Private room         3671
# 2      Shared room           63

# %%
figure=plt.figure(figsize=[20,10])
plt.bar(room_types.index,room_types.to_list(),color=['red','orange',"green"],width=0.2)
plt.xlabel("Room Types")
plt.ylabel("Room counts")
plt.title("Number of Room Types Available")
# Out:
# Text(0.5, 1.0, 'Number of Room Types Available')

# %%
labels = ['Entire home/apt','Private room','Shared room']

explode = (0.1, 0, 0)  # only "explode" the 1st slice

fig1, ax1 = plt.subplots()
ax1.pie(room_counts, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
#Droping the shared room type as its count is very low
airbnb.drop(airbnb.index[airbnb['room_type'] == 'Shared room'], inplace = True)

# %%
airbnb['room_type'].value_counts()
# Out:
# room_type
# Entire home/apt    14937
# Private room        3671
# Name: count, dtype: int64

# %%
#count of each neighborhood to show how popular they are.
airbnb['neighborhood'].value_counts()
# Out:
# neighborhood
# De Baarsjes / Oud West                    3267
# De Pijp / Rivierenbuurt                   2364
# Centrum West                              2208
# Centrum Oost                              1721
# Westerpark                                1422
# Noord-West / Noord-Midden                 1413
# Oud Oost                                  1164
# Bos en Lommer                              980
# Oostelijk Havengebied / Indische Buurt     915
# Watergraafsmeer                            512
# Oud Noord                                  492
# Ijburg / Eiland Zeeburg                    377
# Slotervaart                                345
# Buitenveldert / Zuidas                     248
# Noord West                                 240
# Noord Oost                                 221
# Geuzenveld / Slotermeer                    192
# Osdorp                                     161
# De Aker / Nieuw Sloten                     114
# Bijlmer Centrum                             98
# ...

# %%
neigh_counts=airbnb['neighborhood'].value_counts().to_list()
figure=plt.figure(figsize=[40,20])
plt.bar(airbnb['neighborhood'].value_counts().index,neigh_counts,color='red',)
plt.xlabel("Neighborhood Names")
plt.ylabel("Popularity Counts")
plt.title("Neighborhood Popularity")
# Out:
# Text(0.5, 1.0, 'Neighborhood Popularity')

# %% [markdown]
# From the above graph , it is clear that De Baarsjes / Oud West neighborhood is most popular - 3267 counts and Westpoort neighborhood is least popular - 15 counts

# %%
#Number of reviews that is given for property
reviews_count=pd.Series(airbnb['reviews'].value_counts())
pd.set_option("display.max_rows", None, "display.max_columns", None)
print(reviews_count)
# Out:
# reviews
# 0      2964
# 1      1494
# 2      1232
# 3      1096
# 4       923
# 5       872
# 6       732
# 7       679
# 8       587
# 9       525
# 11      494
# 10      473
# 12      395
# 14      362
# 13      340
# 15      308
# 16      299
# 17      261
# 18      235
# 20      226
# 19      212
# 21      188
# 22      166
# 23      158
# 24      153
# 27      137
# 25      132
# 26      125
# 28      112
# 29      112
# 32      103
# 31       91
# 30       90
# 33       89
# 36       80
# 35       73
# 34       73
# 37       71
# 39       66
# 42       56
# 38       54
# 40       51
# 44       50
# 46       50
# 48       46
# 43       45
# 41       45
# 49       44
# 51       42
# 45       41
# 50       38
# 47       30
# 59       30
# 53       30
# 54       29
# 52       28
# 60       28
# 66       27
# 72       26
# 58       26
# 55       25
# 62       24
# 56       21
# 57       20
# 71       19
# 61       19
# 63       18
# 70       18
# 78       18
# 69       17
# ...

# %%
reviews_count.hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# From the above data and graph, histogram and counts of reviews 0,1,2,3,4,5 for property is comparatively high i.e
#
# 0 - 2964
#
# 1 - 1494
#
# 2 - 1232
#
# 3 - 1096
#
# 4 - 923
#
# 5 - 872

# %%
#overall satisfaction count by each rating
airbnb['overall_satisfaction'].value_counts()
# Out:
# overall_satisfaction
# 5.0    7682
# 0.0    5698
# 4.5    4530
# 4.0     572
# 3.5     105
# 3.0      19
# 2.5       1
# 1.0       1
# Name: count, dtype: int64

# %%
fig=plt.figure(figsize=[20,10])
plt.bar(airbnb['overall_satisfaction'].value_counts().index,airbnb['overall_satisfaction'].value_counts().to_list(),color="green",width=0.2)
plt.xlabel("Satisfaction Ratings")
plt.ylabel("Ratings Counts")
plt.title("Overall Satisfaction Ratings")
# Out:
# Text(0.5, 1.0, 'Overall Satisfaction Ratings')
